# %% [markdown]
# ### Data processing
#
# This notebook shows our approach to combining various datasets into our overall dataset. We combine four datasets of human-generated and machine-generated text from various contexts. To create a balanced final dataset, we take 10,000 samples of human-generated and machine-generated text from each dataset and put them all together into our final dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
essays = pd.read_csv("essays.csv")
grover = pd.read_csv("grover.csv")
reviews = pd.read_csv("reviews.csv")
wiki = pd.read_csv("wiki.csv")

# %% [markdown]
# ### Processing essays

# %%
essays.sample(5)
# Out:
#                                                     text  \
# 11395  I dont't think that we should use the Facial A...
# 20466  The Electoral College has changed between what...
# 42447  Dear senator, The electoral process is extreme...
# 25505  You're the president of your school. You decid...
# 39156  I think dress codes are beneficial to the scho...
#
#                                  prompt_name           source  RDizzl3_seven  \
# 11395            Facial action coding system  persuade_corpus           True
# 20466       Does the electoral college work?  persuade_corpus           True
# 42447       Does the electoral college work?     train_essays           True
# 25505              Seeking multiple opinions  persuade_corpus          False
# 39156  Grades for extracurricular activities     llama_70b_v1          False
#
#          Label
# 11395    Human
# 20466    Human
# 42447    Human
# 25505    Human
# 39156  Machine

# %%
essays['source'].value_counts()
# Out:
# source
# persuade_corpus                       25996
# mistral7binstruct_v1                   2421
# mistral7binstruct_v2                   2421
# chat_gpt_moth                          2421
# llama2_chat                            2421
# kingki19_palm                          1384
# train_essays                           1378
# llama_70b_v1                           1172
# falcon_180b_v1                         1055
# darragh_claude_v6                      1000
# darragh_claude_v7                      1000
# radek_500                               500
# NousResearch/Llama-2-7b-chat-hf         400
# mistralai/Mistral-7B-Instruct-v0.1      400
# cohere-command                          350
# palm-text-bison1                        349
# radekgpt4                               200
# Name: count, dtype: int64

# %%
machine_essays = essays[essays['Label'] == 'Machine'].sample(n = 10000)
human_essays = essays[essays['Label'] == 'Human'].sample(n = 10000)
combined_essays = pd.concat([machine_essays, human_essays])

# %%
combined_essays = combined_essays[['text', 'Label']]
combined_essays['Original dataset'] = 'essays.csv'
combined_essays['Row in original dataset'] = combined_essays.index

# %%
combined_essays.rename(columns = {'text':'Text'}, inplace = True)

# %%
combined_essays
# Out:
#                                                     Text    Label  \
# 38586  Introduction:\nHey there! I came across your p...  Machine
# 40740    Dear [State Senator's Name],\n\nI hope this ...  Machine
# 29120  Pakistan is truly an extraordinary place with ...  Machine
# 42810  This essay will analyze, discuss and prove one...  Machine
# 33554  Dear Principal Smith, \n\nI am writing to you ...  Machine
# ...                                                  ...      ...
# 13950  dear TEACHER_NAME,\n\nI am writing to let you ...    Human
# 43125  Dear, state Senator Electoral College should b...    Human
# 11808  This new technology to read emotional expressi...    Human
# 42735  It's not a secret that we as humans use cars t...    Human
# 24802  Often times, when we're looking for advice we ...    Human
#
#       Original dataset  Row in original dataset
# 38586       essays.csv                    38586
# 40740       essays.csv                    40740
# 29120       essays.csv                    29120
# 42810       essays.csv                    42810
# 33554       essays.csv                    33554
# ...                ...                      ...
# 13950       essays.csv                    13950
# 43125       essays.csv                    43125
# 11808       essays.csv                    11808
# 42735       essays.csv                    42735
# 24802       essays.csv                    24802
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Processing grover

# %%
grover.sample(5)
# Out:
#        Unnamed: 0                                            article  \
# 11349       11349  (CN) – A multi-year judicial panel sparring wi...
# 15975       15975  If you spend most of your day typing, you need...
# 18977       18977  opinion\nGovernment is established in a Republ...
# 4426         4426  Indie media company Oakhurst Entertainment has...
# 13240       13240  5370537724001\nThe incoming federal government...
#
#                    domain                                              title  \
# 11349  courthousenews.com   EU Lawmakers OK Filter to Ease High Court Logjam
# 15975      thenextweb.com  Review: The Keychron K1 and K2 are the wireles...
# 18977       allafrica.com  Gambia: Real Development Versus Cosmetic Devel...
# 4426         deadline.com  ‘Hell Fest’ Co-Writer Seth Sherwood To Helm ‘B...
# 13240    sheppnews.com.au            Election winner must fix school funding
#
#              date          authors  ind30k  \
# 11349  2019-04-09  William Dotinga    7431
# 15975  2019-04-02     Napier Lopez   27232
# 18977  2019-04-05              NaN    8093
# 4426   2019-04-08    Amanda N'Duka   22854
# 13240  2019-04-17              NaN    1105
#
#                                                      url    label  \
# 11349  https://www.courthousenews.com/eu-lawmakers-ok...  machine
# 15975  https://thenextweb.com/plugged/2019/04/02/revi...    human
# 18977    https://allafrica.com/stories/201904050416.html    human
# 4426   https://deadline.com/2019/04/hell-fest-seth-sh...    human
# 13240  https://www.sheppnews.com.au/@national-news/20...    human
#
#          orig_split  split  random_score     top_p
# 11349           gen    val           NaN  0.939683
# 15975  train_burner   test     -0.667901       NaN
# 18977           gen   test     -0.008861       NaN
# 4426   train_burner  train     -0.142662       NaN
# 13240           gen   test     -2.050456       NaN

# %%
grover['label'].value_counts()
# Out:
# label
# human      15000
# machine    10000
# Name: count, dtype: int64

# %%
machine_grover = grover[grover['label'] == 'machine']
human_grover = grover[grover['label'] == 'human'].sample(n = 10000)
combined_grover = pd.concat([machine_grover, human_grover])

# %%
combined_grover['Label'] = combined_grover['label'].apply(lambda x: x.capitalize())
combined_grover['Original dataset'] = 'grover'
combined_grover['Row in original dataset'] = combined_grover.index
combined_grover.rename(columns = {'article':'Text'}, inplace = True)

# %%
combined_grover = combined_grover[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_grover
# Out:
#                                                     Text    Label  \
# 1      When I first started looking at oil assets, I ...  Machine
# 4      The Kingston and St Andrew Municipal Corporati...  Machine
# 5      news, local-news,\nTwo protests against an inv...  Machine
# 7      Drink-driving charges brought against Danny Dr...  Machine
# 13     Called by the Mirror after today's strong new ...  Machine
# ...                                                  ...      ...
# 19575  Colorado lawmakers gave final approval Wednesd...    Human
# 8782   China on Wednesday said the issue of designati...    Human
# 11141  Opinion: the HSE has almost exhausted their 20...    Human
# 23389  Your Android phone could soon replace your har...    Human
# 38     Banffshire and Buchan MSP Stewart Stevenson ye...    Human
#
#       Original dataset  Row in original dataset
# 1               grover                        1
# 4               grover                        4
# 5               grover                        5
# 7               grover                        7
# 13              grover                       13
# ...                ...                      ...
# 19575           grover                    19575
# 8782            grover                     8782
# 11141           grover                    11141
# 23389           grover                    23389
# 38              grover                       38
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Processing reviews

# %%
reviews.sample(5)
# Out:
#                            category  rating label  \
# 6637          Sports_and_Outdoors_5     5.0    OR
# 9595                  Electronics_5     5.0    OR
# 37366  Clothing_Shoes_and_Jewelry_5     4.0    CG
# 10460                 Electronics_5     5.0    CG
# 38634  Clothing_Shoes_and_Jewelry_5     5.0    CG
#
#                                                    text_
# 6637   Haven't had a chance to use this hippack yet, ...
# 9595   At this price point, these stands are sturdy, ...
# 37366  Love this watch, very durable and looks great ...
# 10460  FAR FARRR FARRRRR From "Professional".  I have...
# 38634  Like the hat a little small it's fine.Very goo...

# %%
reviews['label'] = reviews['label'].apply(lambda x: 'Human' if x == 'OR' else 'Machine')
reviews.rename(columns = {'label':'Label', 'text_':'Text'}, inplace=True)

# %%
machine_reviews = reviews[reviews['Label'] == 'Machine'].sample(n = 10000)
human_reviews = reviews[reviews['Label'] == 'Human'].sample(n = 10000)
combined_reviews = pd.concat([machine_reviews, human_reviews])

# %%
combined_reviews['Original dataset'] = 'reviews'
combined_reviews['Row in original dataset'] = combined_reviews.index
combined_reviews = combined_reviews[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_reviews
# Out:
#                                                     Text    Label  \
# 3446   I am using them with a set of wide wooden legs...  Machine
# 29982  Book arrived on time.  We have the book on our...  Machine
# 18255  Looks great, but the quality is not as good as...  Machine
# 6209   Pros\n1) Conforms to Milano Gel (Cordura) inst...  Machine
# 22654  My dog didn't show much interest in the food, ...  Machine
# ...                                                  ...      ...
# 4493   Works as described. Did not notice the honeyco...    Human
# 30440  The book covers many ways to build and maintai...    Human
# 31199  This years favorite book. I really wanted to u...    Human
# 37163  I got these for my gf & she loves them. Perfec...    Human
# 21550  I received the product today. My puppy has not...    Human
#
#       Original dataset  Row in original dataset
# 3446           reviews                     3446
# 29982          reviews                    29982
# 18255          reviews                    18255
# 6209           reviews                     6209
# 22654          reviews                    22654
# ...                ...                      ...
# 4493           reviews                     4493
# 30440          reviews                    30440
# 31199          reviews                    31199
# 37163          reviews                    37163
# 21550          reviews                    21550
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Processing wiki

# %%
wiki.sample(5)
# Out:
#        Unnamed: 0        id  \
# 53497       53497   6489017
# 56109       56109  33911743
# 83920       83920  21539624
# 307           307   2170212
# 20630       20630  24860133
#
#                                                      url              title  \
# 53497  https://en.wikipedia.org/wiki/Crystal%20Computing  Crystal Computing
# 56109      https://en.wikipedia.org/wiki/Jason%20Wallace      Jason Wallace
# 83920         https://en.wikipedia.org/wiki/Tony%20Berti         Tony Berti
# 307                 https://en.wikipedia.org/wiki/Screeb             Screeb
# 20630                https://en.wikipedia.org/wiki/Plazi              Plazi
#
#                                               wiki_intro  \
# 53497  Crystal Computing, later renamed Design Design...
# 56109  Jason Wallace (born 1969) is an author living ...
# 83920  Charles Anton Berti, Jr.  (born June 21, 1972,...
# 307    Screeb  is a small village in south-west Conne...
# 20630  Plazi is a Swiss-based international non-profi...
#
#                                          generated_intro  title_len  \
# 53497  Crystal Computing, later renamed Design Design...          2
# 56109  Jason Wallace (born 1969) is an author, speake...          2
# 83920  Charles Anton Berti, Jr.  (born June 15, 1953)...          2
# 307    Screeb  is a small village in the county of Cu...          1
# 20630  Plazi is a Swiss-based international non-profi...          1
#
#        wiki_intro_len  generated_intro_len  \
# 53497             221                  201
# 56109             163                  178
# 83920             185                  199
# 307               158                  215
# 20630             184                  188
#
#                                                   prompt  \
# 53497  200 word wikipedia style introduction on 'Crys...
# 56109  200 word wikipedia style introduction on 'Jaso...
# 83920  200 word wikipedia style introduction on 'Tony...
# 307    200 word wikipedia style introduction on 'Scre...
# 20630  200 word wikipedia style introduction on 'Plaz...
#
#                                           generated_text  prompt_tokens  \
# 53497   a research project at Xerox PARC in the early...             24
# 56109  , speaker, and entrepreneur. Wallace is the co...             24
# 83920   15, 1953) is an American actor and comedian.\...             27
# 307     the county of Cumbria, England, close to the ...             25
# 20630   that aims to promote sustainability.\n\nPlazi...             27
#
#        generated_text_tokens
# 53497                    238
# 56109                    234
# 83920                    300
# 307                      299
# 20630                    250

# %%
wiki = wiki.sample(n = 20000)

# %%
human_wiki = pd.DataFrame(wiki.iloc[:10000])
machine_wiki = pd.DataFrame(wiki.iloc[10000:])

# %%
human_wiki.rename(columns = {'wiki_intro':'Text'}, inplace = True)
machine_wiki.rename(columns = {'generated_intro':'Text'}, inplace = True)

# %%
human_wiki['Label'] = 'Human'
machine_wiki['Label'] = 'Machine'

# %%
combined_wiki = pd.concat([human_wiki, machine_wiki])

# %%
combined_wiki['Original dataset'] = 'wiki'
combined_wiki['Row in original dataset'] = combined_wiki.index
combined_wiki = combined_wiki[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_wiki
# Out:
#                                                      Text    Label  \
# 82246   WIST may refer to:  WIST-FM, a radio station (...    Human
# 107829  Wilhelm Vöge (16 February 1868 – 30 December 1...    Human
# 133832  Brood XXIII (also known as the Mississippi Val...    Human
# 99298   Eliza Taylor Ransom (May 31, 1863 – June 7, 19...    Human
# 24841   St Bene't's is a Church of England parish chur...    Human
# ...                                                   ...      ...
# 80169   VisualSim Architect is an electronic system-le...  Machine
# 127684  Joel-Peter Witkin (born September 13, 1939) is...  Machine
# 15268   A stock statement is a business statement that...  Machine
# 119902  Pamela Beryl Harriman (née Digby; 20 March 192...  Machine
# 32664   Sir William Denis Battershill KCMG (29 June 18...  Machine
#
#        Original dataset  Row in original dataset
# 82246              wiki                    82246
# 107829             wiki                   107829
# 133832             wiki                   133832
# 99298              wiki                    99298
# 24841              wiki                    24841
# ...                 ...                      ...
# 80169              wiki                    80169
# 127684             wiki                   127684
# 15268              wiki                    15268
# 119902             wiki                   119902
# 32664              wiki                    32664
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Putting it all together

# %%
combined = pd.concat([combined_essays, combined_grover, combined_reviews, combined_wiki])

# %%
combined.to_csv('combined_data.csv', index = False)

# %%
combined['Label'].value_counts()
# Out:
# Label
# Machine    40000
# Human      40000
# Name: count, dtype: int64

# %%
combined['Original dataset'
