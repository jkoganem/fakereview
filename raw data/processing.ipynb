# %% [markdown]
# ### Data processing
#
# This notebook shows our approach to combining various datasets into our overall dataset. We combine four datasets of human-generated and machine-generated text from various contexts. To create a balanced final dataset, we take 10,000 samples of human-generated and machine-generated text from each dataset and put them all together into our final dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
essays = pd.read_csv("essays_balanced.csv")
grover = pd.read_csv("grover.csv")
reviews = pd.read_csv("reviews.csv")
wiki = pd.read_csv("wiki.csv")

# %% [markdown]
# ### Processing essays

# %%
essays.sample(5)
# Out:
#        Unnamed: 0                                               text  \
# 10968       14333  Dear, Principal\n\nIf your trying to decide if...
# 2041        40984   Advantages of Limiting Car Usage\n\nIn recent...
# 12894       17200  Driverless cars really fasinates me. In the ne...
# 10021       12282  What is that thing on Mars?\n\nWell, some peop...
# 32            853  What makes a mistake something someone will ne...
#
#               prompt_name                              source  RDizzl3_seven  \
# 10968   Community service                     persuade_corpus          False
# 2041      Car-free cities  mistralai/Mistral-7B-Instruct-v0.1           True
# 12894     Driverless cars                     persuade_corpus           True
# 10021    The Face on Mars                     persuade_corpus           True
# 32     Phones and driving                     persuade_corpus          False
#
#          Label
# 10968    Human
# 2041   Machine
# 12894    Human
# 10021    Human
# 32       Human

# %%
essays['source'].value_counts()
# Out:
# source
# persuade_corpus                       9515
# llama2_chat                           1312
# mistral7binstruct_v2                  1177
# mistral7binstruct_v1                  1145
# chat_gpt_moth                         1086
# llama_70b_v1                           856
# darragh_claude_v6                      827
# darragh_claude_v7                      813
# falcon_180b_v1                         752
# kingki19_palm                          674
# train_essays                           485
# palm-text-bison1                       305
# cohere-command                         296
# radek_500                              253
# mistralai/Mistral-7B-Instruct-v0.1     214
# NousResearch/Llama-2-7b-chat-hf        186
# radekgpt4                              104
# Name: count, dtype: int64

# %%
essays.groupby(by = 'prompt_name')['source'].value_counts().head(50)
# Out:
# prompt_name                    source
# "A Cowboy Who Rode the Waves"  persuade_corpus                       524
#                                darragh_claude_v7                      73
#                                darragh_claude_v6                      68
#                                llama2_chat                            66
#                                llama_70b_v1                           54
#                                cohere-command                         50
#                                palm-text-bison1                       50
#                                chat_gpt_moth                          47
#                                falcon_180b_v1                         46
#                                mistral7binstruct_v2                   36
#                                mistral7binstruct_v1                   34
# Car-free cities                persuade_corpus                       699
#                                kingki19_palm                         303
#                                train_essays                          244
#                                radek_500                             117
#                                mistralai/Mistral-7B-Instruct-v0.1    105
#                                NousResearch/Llama-2-7b-chat-hf        88
#                                llama_70b_v1                           85
#                                falcon_180b_v1                         81
#                                radekgpt4                              46
#                                darragh_claude_v7                      26
#                                palm-text-bison1                       24
#                                cohere-command                         21
#                                darragh_claude_v6                      21
#                                chat_gpt_moth                          10
#                                mistral7binstruct_v2                    7
#                                llama2_chat                             5
#                                mistral7binstruct_v1                    4
# Cell phones at school          persuade_corpus                       463
#                                llama2_chat                            81
#                                darragh_claude_v6                      68
#                                darragh_claude_v7                      64
#                                mistral7binstruct_v2                   60
#                                mistral7binstruct_v1                   58
#                                chat_gpt_moth                          49
#                                llama_70b_v1                           42
#                                falcon_180b_v1                         41
# Community service              persuade_corpus                       550
#                                llama2_chat                           109
#                                mistral7binstruct_v2                  105
#                                mistral7binstruct_v1                   84
#                                darragh_claude_v6                      65
#                                chat_gpt_moth                          64
#                                darragh_claude_v7                      53
#                                llama_70b_v1                           40
#                                falcon_180b_v1                         30
# Distance learning              persuade_corpus                       942
#                                chat_gpt_moth                         226
#                                mistral7binstruct_v2                  211
#                                mistral7binstruct_v1                  208
# Name: count, dtype: int64

# %%
machine_essays = essays[essays['Label'] == 'Machine'].sample(n = 10000)
human_essays = essays[essays['Label'] == 'Human'].sample(n = 10000)
combined_essays = pd.concat([machine_essays, human_essays])

# %%
combined_essays = combined_essays[['text', 'Label', 'source']]
combined_essays['Original dataset'] = 'essays'
combined_essays['Row in original dataset'] = combined_essays.index

# %%
combined_essays.rename(columns = {'text':'Text', 'source':'Model'}, inplace = True)

# %%
combined_essays.loc[combined_essays['Label'] == 'Human', 'Model'] = 'Human'

# %%
combined_essays
# Out:
#                                                     Text    Label  \
# 13355  While driverless cars present many promising b...  Machine
# 7249   Homework Clubs: The Key to Unlocking Academic ...  Machine
# 2603   "The legalization of marijuana has been a cont...  Machine
# 3993   Taking the opportunity to learn new things can...  Machine
# 3773    Working with a partner is an effective way fo...  Machine
# ...                                                  ...      ...
# 12907  People are always interested in looking in the...    Human
# 1556   The majority of Americans have the luxury of o...    Human
# 16441  Students that live far away from schools or li...    Human
# 15362  Dear Principal,\n\nI think you should go with ...    Human
# 5049   I think you sould go on a few cattle-boat ride...    Human
#
#                       Model Original dataset  Row in original dataset
# 13355     darragh_claude_v7           essays                    13355
# 7249            llama2_chat           essays                     7249
# 2603         falcon_180b_v1           essays                     2603
# 3993   mistral7binstruct_v1           essays                     3993
# 3773   mistral7binstruct_v2           essays                     3773
# ...                     ...              ...                      ...
# 12907                 Human           essays                    12907
# 1556                  Human           essays                     1556
# 16441                 Human           essays                    16441
# 15362                 Human           essays                    15362
# 5049                  Human           essays                     5049
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Processing grover

# %%
grover.sample(5)
# Out:
#        Unnamed: 0                                            article  \
# 23669       23669  Posted\nA Florida man who authorities believe ...
# 3582         3582  A 36-year-old man from Oban has appeared in co...
# 11197       11197  A Nevada judge has dismissed a lawsuit by ranc...
# 15859       15859  HARRISBURG, Pa. (AP) — A grand jury report on ...
# 4984         4984  Board members play a critical role as gatekeep...
#
#                  domain                                              title  \
# 23669        abc.net.au       Cassowary kills suspected breeder in Florida
# 3582   thecourier.co.uk  Man appears in court after biker suffers leg i...
# 11197    oregonlive.com  Cliven Bundy’s public lands claim is 'simply d...
# 15859      pennlive.com  Grand jury sees ways to reduce Pennsylvania’s ...
# 4984    theprovince.com  Lubomyr Luciuk: Trying to uphold Canada's refu...
#
#              date                                     authors  ind30k  \
# 23669  2019-04-14         Australian Broadcasting Corporation   26715
# 3582   2019-04-16                               Ross Gardiner    9735
# 11197  2019-04-09  Maxine Bernstein, The Oregonian Oregonlive   23408
# 15859  2019-04-15         Mark Scolforo, The Associated Press     210
# 4984   2019-04-17         Lubomyr Luciuk, More Lubomyr Luciuk   24194
#
#                                                      url    label  \
# 23669  https://www.abc.net.au/news/2019-04-14/florida...    human
# 3582   https://www.thecourier.co.uk/fp/news/local/per...  machine
# 11197  https://www.oregonlive.com/crime/2019/04/clive...    human
# 15859  https://www.pennlive.com/news/2019/04/grand-ju...  machine
# 4984   https://theprovince.com/opinion/op-ed/lubomyr-...    human
#
#          orig_split  split  random_score     top_p
# 23669  train_burner   test      1.224442       NaN
# 3582            gen  train           NaN  0.939683
# 11197  train_burner    val     -0.181267       NaN
# 15859           gen   test           NaN  0.939683
# 4984   train_burner  train     -0.002763       NaN

# %%
grover['label'].value_counts()
# Out:
# label
# human      15000
# machine    10000
# Name: count, dtype: int64

# %%
machine_grover = grover[grover['label'] == 'machine']
human_grover = grover[grover['label'] == 'human'].sample(n = 10000)
combined_grover = pd.concat([machine_grover, human_grover])

# %%
combined_grover['Label'] = combined_grover['label'].apply(lambda x: x.capitalize())
combined_grover['Original dataset'] = 'grover'
combined_grover['Row in original dataset'] = combined_grover.index
combined_grover.rename(columns = {'article':'Text'}, inplace = True)

# %%
combined_grover = combined_grover[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_grover['Model'] = 'Grover'
combined_grover.loc[combined_grover['Label'] == 'Human', 'Model'] = 'Human'

# %%
combined_grover
# Out:
#                                                     Text    Label  \
# 1      When I first started looking at oil assets, I ...  Machine
# 4      The Kingston and St Andrew Municipal Corporati...  Machine
# 5      news, local-news,\nTwo protests against an inv...  Machine
# 7      Drink-driving charges brought against Danny Dr...  Machine
# 13     Called by the Mirror after today's strong new ...  Machine
# ...                                                  ...      ...
# 10700  Players in the construction and building mater...    Human
# 13710  A 68-year-old man has been sentenced to 90 day...    Human
# 10675  A Carnival cruise ship helped the U.S. Coast G...    Human
# 20319  life-style,\nHUNTING for rocks might not sound...    Human
# 20698  Brian Wilson, Tom Petty, Ringo Starr, Eric Cla...    Human
#
#       Original dataset  Row in original dataset   Model
# 1               grover                        1  Grover
# 4               grover                        4  Grover
# 5               grover                        5  Grover
# 7               grover                        7  Grover
# 13              grover                       13  Grover
# ...                ...                      ...     ...
# 10700           grover                    10700   Human
# 13710           grover                    13710   Human
# 10675           grover                    10675   Human
# 20319           grover                    20319   Human
# 20698           grover                    20698   Human
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Processing reviews

# %%
reviews.sample(5)
# Out:
#                     category  rating label  \
# 20454         Pet_Supplies_5     4.0    OR
# 6200   Sports_and_Outdoors_5     5.0    CG
# 26185         Kindle_Store_5     2.0    CG
# 22051         Pet_Supplies_5     3.0    OR
# 13976        Movies_and_TV_5     5.0    OR
#
#                                                    text_
# 20454  One of my dogs liked it, the other did not!  S...
# 6200   Super comfortable.  Hard to find a better qual...
# 26185  I received this ebook at a discount in exchang...
# 22051  Unfortunately, my 5 cats only found them fun f...
# 13976  We are enjoying this series and are looking fo...

# %%
reviews['label'] = reviews['label'].apply(lambda x: 'Human' if x == 'OR' else 'Machine')
reviews.rename(columns = {'label':'Label', 'text_':'Text'}, inplace=True)

# %%
machine_reviews = reviews[reviews['Label'] == 'Machine'].sample(n = 10000)
human_reviews = reviews[reviews['Label'] == 'Human'].sample(n = 10000)
combined_reviews = pd.concat([machine_reviews, human_reviews])

# %%
combined_reviews['Original dataset'] = 'reviews'
combined_reviews['Row in original dataset'] = combined_reviews.index
combined_reviews = combined_reviews[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_reviews['Model'] = "GPT-2"
combined_reviews.loc[combined_reviews['Label'] == 'Human', 'Model'] = 'Human'

# %%
combined_reviews
# Out:
#                                                     Text    Label  \
# 16594  Not a convenient size and looks a little cheap...  Machine
# 30221  Mysteries are usually good books, but I though...  Machine
# 17121  a little tough to get into. The only problem i...  Machine
# 11022  This product is perfect for what it is intende...  Machine
# 502    Beautiful heavy weight dining room rug. The qu...  Machine
# ...                                                  ...      ...
# 24514  Outstanding! I cannot wait to see what happens...    Human
# 24914  Mr. Reasoner's story of three different cultur...    Human
# 10607  Some obvious quality control issues.  One batt...    Human
# 21696  I can't believe how much the dogs loved this t...    Human
# 3103   <div id="video-block-RCLJDSSDKWYNA" class="a-s...    Human
#
#       Original dataset  Row in original dataset  Model
# 16594          reviews                    16594  GPT-2
# 30221          reviews                    30221  GPT-2
# 17121          reviews                    17121  GPT-2
# 11022          reviews                    11022  GPT-2
# 502            reviews                      502  GPT-2
# ...                ...                      ...    ...
# 24514          reviews                    24514  Human
# 24914          reviews                    24914  Human
# 10607          reviews                    10607  Human
# 21696          reviews                    21696  Human
# 3103           reviews                     3103  Human
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Processing wiki

# %%
wiki.sample(5)
# Out:
#         Unnamed: 0        id  \
# 50731        50731   1008089
# 11682        11682  46820994
# 56045        56045  14521980
# 41917        41917  30335473
# 148977      148977    207746
#
#                                                       url           title  \
# 50731          https://en.wikipedia.org/wiki/Holy%20Brook      Holy Brook
# 11682             https://en.wikipedia.org/wiki/Blutzeuge       Blutzeuge
# 56045   https://en.wikipedia.org/wiki/Granger%20%28nam...  Granger (name)
# 41917          https://en.wikipedia.org/wiki/All%20things      All things
# 148977           https://en.wikipedia.org/wiki/Plagiaulax      Plagiaulax
#
#                                                wiki_intro  \
# 50731   The Holy Brook is a channel of the River Kenne...
# 11682   Blutzeuge (German for "blood witness") was a t...
# 56045   Granger is a surname of English and French ori...
# 41917   "all things" is the seventeenth episode of the...
# 148977  Plagiaulax is a genus of mammal from the Lower...
#
#                                           generated_intro  title_len  \
# 50731   The Holy Brook is a channel of water that orig...          2
# 11682   Blutzeuge (German for "blood witness") was a N...          1
# 56045   Granger is a surname of English and Scottish o...          2
# 41917   "all things" is the seventeenth episode of the...          2
# 148977  Plagiaulax is a genus of mammal from the famil...          1
#
#         wiki_intro_len  generated_intro_len  \
# 50731              157                  196
# 11682              189                  126
# 56045              309                   34
# 41917              198                  136
# 148977             153                   82
#
#                                                    prompt  \
# 50731   200 word wikipedia style introduction on 'Holy...
# 11682   200 word wikipedia style introduction on 'Blut...
# 56045   200 word wikipedia style introduction on 'Gran...
# 41917   200 word wikipedia style introduction on 'All ...
# 148977  200 word wikipedia style introduction on 'Plag...
#
#                                            generated_text  prompt_tokens  \
# 50731    water that originates in the White Mountains ...             22
# 11682    Nazi propaganda term for a person who reports...             30
# 56045    Scottish origin. Notable people with the surn...             24
# 41917    the first season of the American television s...             25
# 148977   the family Eulipotyphlopidae. The genus conta...             29
#
#         generated_text_tokens
# 50731                     226
# 11682                     142
# 56045                      53
# 41917                     166
# 148977                    123

# %%
wiki = wiki.sample(n = 20000)

# %%
human_wiki = pd.DataFrame(wiki.iloc[:10000])
machine_wiki = pd.DataFrame(wiki.iloc[10000:])

# %%
human_wiki.rename(columns = {'wiki_intro':'Text'}, inplace = True)
machine_wiki.rename(columns = {'generated_intro':'Text'}, inplace = True)

# %%
human_wiki['Label'] = 'Human'
machine_wiki['Label'] = 'Machine'

# %%
combined_wiki = pd.concat([human_wiki, machine_wiki])

# %%
combined_wiki['Original dataset'] = 'wiki'
combined_wiki['Row in original dataset'] = combined_wiki.index
combined_wiki = combined_wiki[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_wiki['Model'] = "GPT-3 (Curie)"
combined_wiki.loc[combined_wiki['Label'] == 'Human', 'Model'] = 'Human'

# %%
combined_wiki
# Out:
#                                                      Text    Label  \
# 108221  Decatur may refer to a number of places, stree...    Human
# 27528   Joseph Jacques Omer Plante (; January 17, 1929...    Human
# 79953   Michael Dana Butcher (born May 10, 1965) is an...    Human
# 113863  The Winnipeg Art Gallery (WAG) is an art museu...    Human
# 123850  Andrea Fantoni (1659–1734) was an Italian scul...    Human
# ...                                                   ...      ...
# 72827   The Battle of Lewisham took place on 8 May 180...  Machine
# 106421  Asher Wright (September 7, 1803 – April 21, 18...  Machine
# 16338   LimeWire is a discontinued free software peer-...  Machine
# 53934   The term Diocese of Canada may refer to: \n\n1...  Machine
# 15362   New tribalism is a theory by queer theorist Ju...  Machine
#
#        Original dataset  Row in original dataset          Model
# 108221             wiki                   108221          Human
# 27528              wiki                    27528          Human
# 79953              wiki                    79953          Human
# 113863             wiki                   113863          Human
# 123850             wiki                   123850          Human
# ...                 ...                      ...            ...
# 72827              wiki                    72827  GPT-3 (Curie)
# 106421             wiki                   106421  GPT-3 (Curie)
# 16338              wiki                    16338  GPT-3 (Curie)
# 53934              wiki                    53934  GPT-3 (Curie)
# 15362              wiki                    15362  GPT-3 (Curie)
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Putting it all together

# %%
combined = pd.concat([combined_essays, combined_grover, combined_reviews, combined_wiki])

# %%
combined.to_csv('combined_data.csv', index = False)

# %%
combined['Label'].value_counts()
# Out:
# Label
# Machine    40000
# Human      40000
# Name: count, dtype: int64

# %%
combined['Original dataset'].value_counts()
# Out:
# Original dataset
# essays     20000
# grover     20000
# reviews    20000
# wiki       20000
# Name: count, dtype: int64

# %%
combined
# Out:
#                                                      Text    Label  \
# 13355   While driverless cars present many promising b...  Machine
# 7249    Homework Clubs: The Key to Unlocking Academic ...  Machine
# 2603    "The legalization of marijuana has been a cont...  Machine
# 3993    Taking the opportunity to learn new things can...  Machine
# 3773     Working with a partner is an effective way fo...  Machine
# ...                                                   ...      ...
# 72827   The Battle of Lewisham took place on 8 May 180...  Machine
# 106421  Asher Wright (September 7, 1803 – April 21, 18...  Machine
# 16338   LimeWire is a discontinued free software peer-...  Machine
# 53934   The term Diocese of Canada may refer to: \n\n1...  Machine
# 15362   New tribalism is a theory by queer theorist Ju...  Machine
#
#                        Model Original dataset  Row in original dataset
# 13355      darragh_claude_v7           essays                    13355
# 7249             llama2_chat           essays                     7249
# 2603          falcon_180b_v1           essays                     2603
# 3993    mistral7binstruct_v1           essays                     3993
# 3773    mistral7binstruct_v2           essays                     3773
# ...                      ...              ...                      ...
# 72827          GPT-3 (Curie)             wiki                    72827
# 106421         GPT-3 (Curie)             wiki                   106421
# 16338          GPT-3 (Curie)             wiki                    16338
# 53934          GPT-3 (Curie)             wiki                    53934
# 15362          GPT-3 (Curie)             wiki                    15362
#
# [80000 rows x 5 columns]
