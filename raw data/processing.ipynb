# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
essays = pd.read_csv("essays.csv")
grover = pd.read_csv("grover.csv")
reviews = pd.read_csv("reviews.csv")
wiki = pd.read_csv("wiki.csv")

# %% [markdown]
# ### Processing essays

# %%
essays.sample(5)
# Out:
#                                                     text  \
# 14161  Dear Principle,\n\nI think that students shoul...
# 16139  STUDENT_NAME\n\nOTHER_NAME\n\nOTHER_NAME\n\n3-...
# 2449   What are the biggest advantages of limiting ca...
# 26547   I believe that setting a good example is the ...
# 5444   You should join the Seagoing Cowboys! In this ...
#
#                                  prompt_name                source  \
# 14161                      Community service       persuade_corpus
# 16139  Grades for extracurricular activities       persuade_corpus
# 2449                         Car-free cities       persuade_corpus
# 26547              Seeking multiple opinions  mistral7binstruct_v2
# 5444           "A Cowboy Who Rode the Waves"       persuade_corpus
#
#        RDizzl3_seven    Label
# 14161          False    Human
# 16139          False    Human
# 2449            True    Human
# 26547          False  Machine
# 5444            True    Human

# %%
essays['source'].value_counts()
# Out:
# source
# persuade_corpus                       25996
# mistral7binstruct_v1                   2421
# mistral7binstruct_v2                   2421
# chat_gpt_moth                          2421
# llama2_chat                            2421
# kingki19_palm                          1384
# train_essays                           1378
# llama_70b_v1                           1172
# falcon_180b_v1                         1055
# darragh_claude_v6                      1000
# darragh_claude_v7                      1000
# radek_500                               500
# NousResearch/Llama-2-7b-chat-hf         400
# mistralai/Mistral-7B-Instruct-v0.1      400
# cohere-command                          350
# palm-text-bison1                        349
# radekgpt4                               200
# Name: count, dtype: int64

# %%
machine_essays = essays[essays['Label'] == 'Machine'].sample(n = 10000)
human_essays = essays[essays['Label'] == 'Human'].sample(n = 10000)
training_essays = pd.concat([machine_essays, human_essays])

# %%
training_essays = training_essays[['text', 'Label']]
training_essays['Original dataset'] = 'essays.csv'
training_essays['Row in original dataset'] = training_essays.index

# %%
training_essays.rename(columns = {'text':'Text'}, inplace = True)

# %%
training_essays
# Out:
#                                                     Text    Label  \
# 33800  Title: The Power of Praise and Achievements on...  Machine
# 39314  The rise of technology has brought about signi...  Machine
# 26585  High school is a crucial part of a person's li...  Machine
# 34420  Sure, here's my attempt at writing an essay re...  Machine
# 40244  The prospect of implementing a four-day school...  Machine
# ...                                                  ...      ...
# 21116  Dear TEACHER_NAME,\n\nFriday, January 28th, 20...    Human
# 43183  Florida Senator I had not known much about the...    Human
# 7880   Do you feel tired, over stressed, and ready to...    Human
# 10796  Whats the Facial Coding System you asked ? Wha...    Human
# 799    Distracted Driving\n\nDistracted driving has b...    Human
#
#       Original dataset  Row in original dataset
# 33800       essays.csv                    33800
# 39314       essays.csv                    39314
# ...

# %% [markdown]
# ### Processing grover

# %%
grover.sample(5)
# Out:
#        Unnamed: 0                                            article  \
# 17715       17715  A TAXIDERMY shop owner has launched an urgent ...
# 9504         9504  sport, local-sport,\nINDIVIDUAL trials are the...
# 16429       16429  This content was published on April 12, 2019 1...
# 22488       22488  When a mother thought that her husband loved t...
# 19715       19715  The most influential Patriot you’d never heard...
#
#                   domain                                              title  \
# 17715    dailystar.co.uk  NHS launches FREE BEER prescriptions for run-d...
# 9504    theherald.com.au  South Newcastle Lions team preview 2019 - Newc...
# 16429       swissinfo.ch  Football Leaks probe closed against Swiss pros...
# 22488  opposingviews.com  Jealous Mom Thinks Husband Loves 3-Week-Old Da...
# 19715         boston.com  Jack Easterby, departed Patriots character coa...
#
#              date               authors  ind30k  \
# ...

# %%
grover['label'].value_counts()
# Out:
# label
# human      15000
# machine    10000
# Name: count, dtype: int64

# %%
machine_grover = grover[grover['label'] == 'machine']
human_grover = grover[grover['label'] == 'human'].sample(n = 10000)
training_grover = pd.concat([machine_grover, human_grover])

# %%
training_grover['Label'] = training_grover['label'].apply(lambda x: x.capitalize())
training_grover['Original dataset'] = 'grover'
training_grover['Row in original dataset'] = training_grover.index
training_grover.rename(columns = {'article':'Text'}, inplace = True)

# %%
training_grover = training_grover[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
training_grover
# Out:
#                                                     Text    Label  \
# 1      When I first started looking at oil assets, I ...  Machine
# 4      The Kingston and St Andrew Municipal Corporati...  Machine
# 5      news, local-news,\nTwo protests against an inv...  Machine
# 7      Drink-driving charges brought against Danny Dr...  Machine
# 13     Called by the Mirror after today's strong new ...  Machine
# ...                                                  ...      ...
# 7425   Hyderabad: Attacking the Bharatiya Janata Part...    Human
# 23303  At age 16, Omar Arafat just became a published...    Human
# 18418  PHOENIX (AP) — Joe Ingles has the green light ...    Human
# 21652  While heading into the eighth and final season...    Human
# 543    A comprehensive report recapping developments ...    Human
#
#       Original dataset  Row in original dataset
# 1               grover                        1
# 4               grover                        4
# ...

# %% [markdown]
# ### Processing reviews

# %%
reviews.sample(5)
# Out:
#                            category  rating label  \
# 6015          Sports_and_Outdoors_5     5.0    OR
# 39373  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 5416          Sports_and_Outdoors_5     5.0    OR
# 7280          Sports_and_Outdoors_5     5.0    CG
# 22788                Pet_Supplies_5     1.0    OR
#
#                                                    text_
# 6015   Unlike the taller socks, these don't feel as t...
# 39373  These are a nice slip-on, but not the most com...
# 5416   i have purchased 15 of the new adidas green st...
# 7280   Very nice sights. They fit perfect on the Gloc...
# 22788  my kitten straight up refused to eat this. i o...

# %%
reviews['label'] = reviews['label'].apply(lambda x: 'Human' if x == 'OR' else 'Machine')
reviews.rename(columns = {'label':'Label', 'text_':'Text'}, inplace=True)

# %%
machine_reviews = reviews[reviews['Label'] == 'Machine'].sample(n = 10000)
human_reviews = reviews[reviews['Label'] == 'Human'].sample(n = 10000)
training_reviews = pd.concat([machine_reviews, human_reviews])

# %%
training_reviews['Original dataset'] = 'reviews'
training_reviews['Row in original dataset'] = training_reviews.index
training_reviews = training_reviews[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
training_reviews
# Out:
#                                                     Text    Label  \
# 18681  I could not be happier with this item. I've us...  Machine
# 13284  We are only half way through the movie.  We ar...  Machine
# 39211  The design of the shoes is a little sloppy, bu...  Machine
# 9393   This inexpensive Garmin is well built and easy...  Machine
# 25873  Really good story. Would have liked more of th...  Machine
# ...                                                  ...      ...
# 23467  If you want the convenience of buying puppy tr...    Human
# 12820  After 39 years, it was time to see this movie ...    Human
# 29108  I have not finished it completely, lost intere...    Human
# 33829  My granddaughter loves the table especially wh...    Human
# 20399  I have a Rottweiler and she loves this toy, an...    Human
#
#       Original dataset  Row in original dataset
# 18681          reviews                    18681
# 13284          reviews                    13284
# ...

# %% [markdown]
# ### Processing wiki

# %%
wiki.sample(5)
# Out:
#         Unnamed: 0        id  \
# 7345          7345  46350716
# 4685          4685  59706264
# 138186      138186  19344639
# 124670      124670  59436661
# 17414        17414   6926950
#
#                                                       url  \
# 7345                 https://en.wikipedia.org/wiki/ReLIFE
# 4685    https://en.wikipedia.org/wiki/John%20Templeton...
# 138186  https://en.wikipedia.org/wiki/Sreevallabha%20T...
# 124670  https://en.wikipedia.org/wiki/Bang%C4%B1r%20Ba...
# 17414   https://en.wikipedia.org/wiki/Ultralight%20bac...
#
#                             title  \
# 7345                       ReLIFE
# 4685    John Templeton Foundation
# 138186        Sreevallabha Temple
# 124670              Bangır Bangır
# 17414      Ultralight backpacking
#
#                                                wiki_intro  \
# 7345    is a Japanese manga series in webtoon format w...
# 4685    The John Templeton Foundation (Templeton Found...
# ...

# %%
wiki = wiki.sample(n = 20000)

# %%
human_wiki = pd.DataFrame(wiki.iloc[:10000])
machine_wiki = pd.DataFrame(wiki.iloc[10000:])

# %%
human_wiki.rename(columns = {'wiki_intro':'Text'}, inplace = True)
machine_wiki.rename(columns = {'generated_intro':'Text'}, inplace = True)

# %%
human_wiki['Label'] = 'Human'
machine_wiki['Label'] = 'Machine'

# %%
training_wiki = pd.concat([human_wiki, machine_wiki])

# %%
training_wiki['Original dataset'] = 'wiki'
training_wiki['Row in original dataset'] = training_wiki.index
training_wiki = training_wiki[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
training_wiki
# Out:
#                                                      Text    Label  \
# 112536  The Chicago City Railway Company (CCRy) was an...    Human
# 105179  The 2014 Al-Safira offensive, code-named "Zaei...    Human
# 24742   In the UK, a Ludlow wall box is a post box whe...    Human
# 48137   Brooks England is a bicycle saddle manufacture...    Human
# 19618   Simbarashe Simbanenduku Mumbengegwi (born 20 J...    Human
# ...                                                   ...      ...
# 128612  Harvey Phillip Pratt (born 1941) is an emeritu...  Machine
# 20705   Albert Hetterle (31 October 1918 – 17 January ...  Machine
# 41055   The West African bichir or retropinnis bichir ...  Machine
# 118857  Marcella "Marcie" Laderman (; born February 1,...  Machine
# 117222  Alice Louisa Dudeney (née Whiffin; 21 October ...  Machine
#
#        Original dataset  Row in original dataset
# 112536             wiki                   112536
# 105179             wiki                   105179
# ...

# %% [markdown]
# ### Putting it all together

# %%
training = pd.concat([training_essays, training_grover, training_reviews, training_wiki])

# %%
training.to_csv('training.csv', index = False)
