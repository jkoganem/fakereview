# %% [markdown]
# ### Data processing
#
# This notebook shows our approach to combining various datasets into our overall dataset. We combine four datasets of human-generated and machine-generated text from various contexts. To create a balanced final dataset, we take 10,000 samples of human-generated and machine-generated text from each dataset and put them all together into our final dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
essays = pd.read_csv("essays.csv")
grover = pd.read_csv("grover.csv")
reviews = pd.read_csv("reviews.csv")
wiki = pd.read_csv("wiki.csv")

# %% [markdown]
# ### Processing essays

# %%
essays.sample(5)
# Out:
#                                                     text  \
# 35310  I recently had an experience that taught me a ...
# 13223  So you think that aliens created the face that...
# 38819  Hey there!  As an 8th grader, I'm super excite...
# 39303  Advantages of Limiting Car Usage\n\nLimiting c...
# 21019  Dear TEACHER_NAME,\n\nI think that we should h...
#
#                      prompt_name           source  RDizzl3_seven    Label
# 35310  Seeking multiple opinions    chat_gpt_moth          False  Machine
# 13223           The Face on Mars  persuade_corpus           True    Human
# 38819          Distance learning      llama2_chat          False  Machine
# 39303            Car-free cities        radek_500           True  Machine
# 21019      Cell phones at school  persuade_corpus          False    Human

# %%
essays['source'].value_counts()
# Out:
# source
# persuade_corpus                       25996
# mistral7binstruct_v1                   2421
# mistral7binstruct_v2                   2421
# chat_gpt_moth                          2421
# llama2_chat                            2421
# kingki19_palm                          1384
# train_essays                           1378
# llama_70b_v1                           1172
# falcon_180b_v1                         1055
# darragh_claude_v6                      1000
# darragh_claude_v7                      1000
# radek_500                               500
# NousResearch/Llama-2-7b-chat-hf         400
# mistralai/Mistral-7B-Instruct-v0.1      400
# cohere-command                          350
# palm-text-bison1                        349
# radekgpt4                               200
# Name: count, dtype: int64

# %%
machine_essays = essays[essays['Label'] == 'Machine'].sample(n = 10000)
human_essays = essays[essays['Label'] == 'Human'].sample(n = 10000)
combined_essays = pd.concat([machine_essays, human_essays])

# %%
combined_essays = combined_essays[['text', 'Label']]
combined_essays['Original dataset'] = 'essays'
combined_essays['Row in original dataset'] = combined_essays.index

# %%
combined_essays.rename(columns = {'text':'Text'}, inplace = True)

# %%
combined_essays
# Out:
#                                                     Text    Label  \
# 26613  The idea of graduating high school in three ye...  Machine
# 26326  Hey, I'm so excited to write this essay about ...  Machine
# 30579  Introduction\n\nSelf-reliance is a concept tha...  Machine
# 33547  Sure, here's my attempt at writing an essay as...  Machine
# 33768  The legalization of marijuana is a highly deba...  Machine
# ...                                                  ...      ...
# 6212   This is why you should join the seagoing cowbo...    Human
# 18030  As I admit that the concept of a driverless ve...    Human
# 12996  In the article "unmasking the face on mars" pe...    Human
# 635    Cell phones have become very popular over the ...    Human
# 13566  Dear Principal,\n\nWe should not be required t...    Human
#
#       Original dataset  Row in original dataset
# 26613           essays                    26613
# 26326           essays                    26326
# 30579           essays                    30579
# 33547           essays                    33547
# 33768           essays                    33768
# ...                ...                      ...
# 6212            essays                     6212
# 18030           essays                    18030
# 12996           essays                    12996
# 635             essays                      635
# 13566           essays                    13566
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Processing grover

# %%
grover.sample(5)
# Out:
#        Unnamed: 0                                            article  \
# 18684       18684  Afghan security forces gather Tuesday near Bag...
# 20246       20246  It's tempting to apply to a new job in the hop...
# 9921         9921  (Front) Chris Evans, Director Joe Russo, Brie ...
# 9558         9558  One person is dead and a firefighter is injure...
# 17171       17171  U.S. Treasurer Jovita Carranza speaks at a for...
#
#                     domain                                              title  \
# 18684   courthousenews.com  3 US Soldiers and a Contractor Killed in Afgha...
# 20246             fool.com  4 Signs You're Applying to a Job for the Wrong...
# 9921          nbcmiami.com  ‘Avengers: Endgame’ Has Sold Nearly Twice as M...
# 9558              necn.com  1 Killed, Firefighter Injured in Fall River Blaze
# 17171  nbcphiladelphia.com  Trump Taps Carranza as Small Business Administ...
#
#              date                                            authors  ind30k  \
# 18684  2019-04-09                                   Associated Press   26816
# 20246  2019-04-15  Maurie Backman, Because They Often Aren'T, She...    5311
# 9921   2019-04-09                                                NaN   23926
# 9558   2019-04-06                                                NaN    7033
# 17171  2019-04-04                                                NaN   20300
#
#                                                      url    label  \
# 18684  https://www.courthousenews.com/3-u-s-soldiers-...    human
# 20246  https://www.fool.com/careers/2019/04/15/4-sign...  machine
# 9921   https://www.nbcmiami.com/entertainment/enterta...    human
# 9558   https://www.necn.com/news/new-england/One-Dead...  machine
# 17171  https://www.nbcphiladelphia.com/news/national-...    human
#
#          orig_split  split  random_score     top_p
# 18684  train_burner   test     -0.066292       NaN
# 20246           gen   test           NaN  0.939683
# 9921   train_burner  train      2.403799       NaN
# 9558            gen  train           NaN  0.939683
# 17171  train_burner   test     -0.401165       NaN

# %%
grover['label'].value_counts()
# Out:
# label
# human      15000
# machine    10000
# Name: count, dtype: int64

# %%
machine_grover = grover[grover['label'] == 'machine']
human_grover = grover[grover['label'] == 'human'].sample(n = 10000)
combined_grover = pd.concat([machine_grover, human_grover])

# %%
combined_grover['Label'] = combined_grover['label'].apply(lambda x: x.capitalize())
combined_grover['Original dataset'] = 'grover'
combined_grover['Row in original dataset'] = combined_grover.index
combined_grover.rename(columns = {'article':'Text'}, inplace = True)

# %%
combined_grover = combined_grover[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_grover
# Out:
#                                                     Text    Label  \
# 1      When I first started looking at oil assets, I ...  Machine
# 4      The Kingston and St Andrew Municipal Corporati...  Machine
# 5      news, local-news,\nTwo protests against an inv...  Machine
# 7      Drink-driving charges brought against Danny Dr...  Machine
# 13     Called by the Mirror after today's strong new ...  Machine
# ...                                                  ...      ...
# 21069  What's happening: Next month in San Francisco,...    Human
# 19792  PSG will be crowned champions on Wednesday if ...    Human
# 16248  Nov. 16, 1929 – March 29, 2019\nSister Elizabe...    Human
# 20646  "Through his band Frightened Rabbit, so many p...    Human
# 24664  Louise Bessette\nMontreal actor and theatre he...    Human
#
#       Original dataset  Row in original dataset
# 1               grover                        1
# 4               grover                        4
# 5               grover                        5
# 7               grover                        7
# 13              grover                       13
# ...                ...                      ...
# 21069           grover                    21069
# 19792           grover                    19792
# 16248           grover                    16248
# 20646           grover                    20646
# 24664           grover                    24664
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Processing reviews

# %%
reviews.sample(5)
# Out:
#                            category  rating label  \
# 17207  Tools_and_Home_Improvement_5     5.0    CG
# 27750                Kindle_Store_5     4.0    CG
# 4755          Sports_and_Outdoors_5     5.0    OR
# 38953  Clothing_Shoes_and_Jewelry_5     5.0    OR
# 20808                Pet_Supplies_5     5.0    OR
#
#                                                    text_
# 17207  Awesome little cutter.  Used it to cut the lon...
# 27750  Jessica McClain is the daughter of an island b...
# 4755   Best tasting trail food we have ever tried, my...
# 38953  This cross is simple but elegant and just the ...
# 20808  We've used this for our previous dogs and now ...

# %%
reviews['label'] = reviews['label'].apply(lambda x: 'Human' if x == 'OR' else 'Machine')
reviews.rename(columns = {'label':'Label', 'text_':'Text'}, inplace=True)

# %%
machine_reviews = reviews[reviews['Label'] == 'Machine'].sample(n = 10000)
human_reviews = reviews[reviews['Label'] == 'Human'].sample(n = 10000)
combined_reviews = pd.concat([machine_reviews, human_reviews])

# %%
combined_reviews['Original dataset'] = 'reviews'
combined_reviews['Row in original dataset'] = combined_reviews.index
combined_reviews = combined_reviews[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_reviews
# Out:
#                                                     Text    Label  \
# 36938  I LOVE this top & it has the quality and comfo...  Machine
# 15675  got this for my son, who has arthritis.  He sa...  Machine
# 10038  I bought this receiver to use with my cell pho...  Machine
# 35443  Fun family game.  With this set, you can play ...  Machine
# 33998  Easy and fun to build. We have had the wooden ...  Machine
# ...                                                  ...      ...
# 367    This is a beautiful table runner and looks gre...    Human
# 2860   I've made candy with these several times alrea...    Human
# 17267  Posting was misleading in that it stated it to...    Human
# 39875  I do have to say that I received this product ...    Human
# 26262  AM has written of robotic soldiers that came f...    Human
#
#       Original dataset  Row in original dataset
# 36938          reviews                    36938
# 15675          reviews                    15675
# 10038          reviews                    10038
# 35443          reviews                    35443
# 33998          reviews                    33998
# ...                ...                      ...
# 367            reviews                      367
# 2860           reviews                     2860
# 17267          reviews                    17267
# 39875          reviews                    39875
# 26262          reviews                    26262
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Processing wiki

# %%
wiki.sample(5)
# Out:
#         Unnamed: 0        id  \
# 118440      118440   7408300
# 15531        15531  20874905
# 35585        35585  59558024
# 65599        65599   6699713
# 64663        64663    360506
#
#                                                       url  \
# 118440  https://en.wikipedia.org/wiki/San%20Andres%2C%...
# 15531        https://en.wikipedia.org/wiki/Lisa%20Wickham
# 35585   https://en.wikipedia.org/wiki/Miss%20Nepal%202019
# 65599       https://en.wikipedia.org/wiki/Thekla%20Reuten
# 64663   https://en.wikipedia.org/wiki/History%20of%20J...
#
#                        title  \
# 118440    San Andres, Manila
# 15531           Lisa Wickham
# 35585        Miss Nepal 2019
# 65599          Thekla Reuten
# 64663   History of Jerusalem
#
#                                                wiki_intro  \
# 118440  San Andres (also San Andres Bukid, bukid being...
# 15531   Lisa Wickham is a media producer-director-TV p...
# 35585   Hidden Treasures Ruslan FM 95.2 Miss Nepal 201...
# 65599   Thekla Simona Gelsomina Reuten (born 16 Septem...
# 64663   During its long history, Jerusalem has been at...
#
#                                           generated_intro  title_len  \
# 118440  San Andres (also San Andres Bukid, bukid meani...          3
# 15531   Lisa Wickham is a media producer-director-TV p...          2
# 35585   Hidden Treasures Ruslan FM 95.2 Miss Nepal 201...          3
# 65599   Thekla Simona Gelsomina Reuten (born 16 Septem...          2
# 64663   During its long history, Jerusalem has been sa...          3
#
#         wiki_intro_len  generated_intro_len  \
# 118440             151                  218
# 15531              205                  229
# 35585              158                   77
# 65599              174                  166
# 64663              188                  247
#
#                                                    prompt  \
# 118440  200 word wikipedia style introduction on 'San ...
# 15531   200 word wikipedia style introduction on 'Lisa...
# 35585   200 word wikipedia style introduction on 'Miss...
# 65599   200 word wikipedia style introduction on 'Thek...
# 64663   200 word wikipedia style introduction on 'Hist...
#
#                                            generated_text  prompt_tokens  \
# 118440   meaning "mountain" in the Tagalog language) i...             31
# 15531   . Wickham has worked in a number of positions ...             28
# 35585    2019\n\nThe Miss Nepal 2019 pageant is a nati...             27
# 65599    1984) is a German singer and songwriter. She ...             33
# 64663    sacked and destroyed numerous times by invadi...             24
#
#         generated_text_tokens
# 118440                    300
# 15531                     297
# 35585                      97
# 65599                     239
# 64663                     300

# %%
wiki = wiki.sample(n = 20000)

# %%
human_wiki = pd.DataFrame(wiki.iloc[:10000])
machine_wiki = pd.DataFrame(wiki.iloc[10000:])

# %%
human_wiki.rename(columns = {'wiki_intro':'Text'}, inplace = True)
machine_wiki.rename(columns = {'generated_intro':'Text'}, inplace = True)

# %%
human_wiki['Label'] = 'Human'
machine_wiki['Label'] = 'Machine'

# %%
combined_wiki = pd.concat([human_wiki, machine_wiki])

# %%
combined_wiki['Original dataset'] = 'wiki'
combined_wiki['Row in original dataset'] = combined_wiki.index
combined_wiki = combined_wiki[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_wiki
# Out:
#                                                      Text    Label  \
# 34604   Deborah Wiles (born May 5, 1953, Mobile, Alaba...    Human
# 138105  In computing, subject-oriented programming is ...    Human
# 120916  Richard Aaron Katz (March 13, 1924 – November ...    Human
# 145880  The geography of Cornwall  describes the extre...    Human
# 71798   David Lewis Fultz (May 29, 1875 – October 29, ...    Human
# ...                                                   ...      ...
# 116735  The 1934 WANFL season was the 50th season of t...  Machine
# 101963  The Salle du Bel-Air or Salle du Bel-Air is a ...  Machine
# 92244   Jasmine Ser Xiang Wei (born 24 September 1987)...  Machine
# 84183   The Nantuo 181 class tug is a Chinese diesel-e...  Machine
# 130060  Air Commodore Cathcart Michael Wight-Boycott, ...  Machine
#
#        Original dataset  Row in original dataset
# 34604              wiki                    34604
# 138105             wiki                   138105
# 120916             wiki                   120916
# 145880             wiki                   145880
# 71798              wiki                    71798
# ...                 ...                      ...
# 116735             wiki                   116735
# 101963             wiki                   101963
# 92244              wiki                    92244
# 84183              wiki                    84183
# 130060             wiki                   130060
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Putting it all together

# %%
combined = pd.concat([combined_essays, combined_grover, combined_reviews, combined_wiki])

# %%
combined.to_csv('combined_data.csv', index = False)

# %%
combined['Label'].value_counts()
# Out:
# Label
# Machine    40000
# Human      40000
# Name: count, dtype: int64

# %%
combined['Original dataset'].value_counts()
# Out:
# Original dataset
# essays     20000
# grover     20000
# reviews    20000
# wiki       20000
# Name: count, dtype: int64
