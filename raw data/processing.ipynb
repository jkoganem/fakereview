# %% [markdown]
# ### Data processing
#
# This notebook shows our approach to combining various datasets into our overall dataset. We combine four datasets of human-generated and machine-generated text from various contexts. To create a balanced final dataset, we take 10,000 samples of human-generated and machine-generated text from each dataset and put them all together into our final dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
essays = pd.read_csv("essays_balanced.csv")
grover = pd.read_csv("grover.csv")
reviews = pd.read_csv("reviews.csv")
wiki = pd.read_csv("wiki.csv")

# %% [markdown]
# ### Processing essays

# %%
essays.sample(5)
# Out:
#        Unnamed: 0                                               text  \
# 6463         7764  All students should be required to join a afte...
# 16574       23298  Some schools offer distance learning as an opt...
# 12292       38064  I believe that the minimum wage in our country...
# 8356        10181  The technology to read people emotional expres...
# 12737       17460  "Driveless Cars Are Coming" this article gives...
#
#                                  prompt_name           source  RDizzl3_seven  \
# 6463    Mandatory extracurricular activities  persuade_corpus          False
# 16574                      Distance learning  persuade_corpus          False
# 12292  Grades for extracurricular activities   falcon_180b_v1          False
# 8356             Facial action coding system  persuade_corpus           True
# 12737                        Driverless cars  persuade_corpus           True
#
#          Label
# 6463     Human
# 16574    Human
# 12292  Machine
# 8356     Human
# 12737    Human

# %%
essays['source'].value_counts()
# Out:
# source
# persuade_corpus                       9515
# llama2_chat                           1312
# mistral7binstruct_v2                  1177
# mistral7binstruct_v1                  1145
# chat_gpt_moth                         1086
# llama_70b_v1                           856
# darragh_claude_v6                      827
# darragh_claude_v7                      813
# falcon_180b_v1                         752
# kingki19_palm                          674
# train_essays                           485
# palm-text-bison1                       305
# cohere-command                         296
# radek_500                              253
# mistralai/Mistral-7B-Instruct-v0.1     214
# NousResearch/Llama-2-7b-chat-hf        186
# radekgpt4                              104
# Name: count, dtype: int64

# %%
essays.groupby(by = 'prompt_name')['source'].value_counts().head(50)
# Out:
# prompt_name                    source
# "A Cowboy Who Rode the Waves"  persuade_corpus                       524
#                                darragh_claude_v7                      73
#                                darragh_claude_v6                      68
#                                llama2_chat                            66
#                                llama_70b_v1                           54
#                                cohere-command                         50
#                                palm-text-bison1                       50
#                                chat_gpt_moth                          47
#                                falcon_180b_v1                         46
#                                mistral7binstruct_v2                   36
#                                mistral7binstruct_v1                   34
# Car-free cities                persuade_corpus                       699
#                                kingki19_palm                         303
#                                train_essays                          244
#                                radek_500                             117
#                                mistralai/Mistral-7B-Instruct-v0.1    105
#                                NousResearch/Llama-2-7b-chat-hf        88
#                                llama_70b_v1                           85
#                                falcon_180b_v1                         81
#                                radekgpt4                              46
#                                darragh_claude_v7                      26
#                                palm-text-bison1                       24
#                                cohere-command                         21
#                                darragh_claude_v6                      21
#                                chat_gpt_moth                          10
#                                mistral7binstruct_v2                    7
#                                llama2_chat                             5
#                                mistral7binstruct_v1                    4
# Cell phones at school          persuade_corpus                       463
#                                llama2_chat                            81
#                                darragh_claude_v6                      68
#                                darragh_claude_v7                      64
#                                mistral7binstruct_v2                   60
#                                mistral7binstruct_v1                   58
#                                chat_gpt_moth                          49
#                                llama_70b_v1                           42
#                                falcon_180b_v1                         41
# Community service              persuade_corpus                       550
#                                llama2_chat                           109
#                                mistral7binstruct_v2                  105
#                                mistral7binstruct_v1                   84
#                                darragh_claude_v6                      65
#                                chat_gpt_moth                          64
#                                darragh_claude_v7                      53
#                                llama_70b_v1                           40
#                                falcon_180b_v1                         30
# Distance learning              persuade_corpus                       942
#                                chat_gpt_moth                         226
#                                mistral7binstruct_v2                  211
#                                mistral7binstruct_v1                  208
# Name: count, dtype: int64

# %%
machine_essays = essays[essays['Label'] == 'Machine'].sample(n = 10000)
human_essays = essays[essays['Label'] == 'Human'].sample(n = 10000)
combined_essays = pd.concat([machine_essays, human_essays])

# %%
combined_essays = combined_essays[['text', 'Label', 'source']]
combined_essays['Original dataset'] = 'essays'
combined_essays['Row in original dataset'] = combined_essays.index

# %%
combined_essays.rename(columns = {'text':'Text', 'source':'Source'}, inplace = True)

# %%
combined_essays
# Out:
#                                                     Text    Label  \
# 12494  Hi my name is Timmy and I’m in grade 7. Homewo...  Machine
# 6853   Graduating from high school a year early may s...  Machine
# 14687   Dear state senator,\n\nI am writing to expres...  Machine
# 465    Cell phones have become an essential part of o...  Machine
# 14846  Dear Senator,\n\nI am writing to you today to ...  Machine
# ...                                                  ...      ...
# 967    L\n\nimiting car usage is a great and helpful ...    Human
# 13995  Dear President of the United States,\n\nI thin...    Human
# 403    Should drivers be able to use their phone whil...    Human
# 16369  Many students in the U.S. are being advised to...    Human
# 16273  It's good idea to receive distance learning? W...    Human
#
#                 Source Original dataset  Row in original dataset
# 12494     llama_70b_v1           essays                    12494
# 6853     chat_gpt_moth           essays                     6853
# 14687   cohere-command           essays                    14687
# 465     falcon_180b_v1           essays                      465
# 14846    kingki19_palm           essays                    14846
# ...                ...              ...                      ...
# 967    persuade_corpus           essays                      967
# 13995  persuade_corpus           essays                    13995
# 403    persuade_corpus           essays                      403
# 16369  persuade_corpus           essays                    16369
# 16273  persuade_corpus           essays                    16273
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Processing grover

# %%
grover.sample(5)
# Out:
#        Unnamed: 0                                            article  \
# 21763       21763  Ge Min, spokesperson for the Washington, D.C. ...
# 22823       22823  As Congress considers a new funding bill, fami...
# 23162       23162  (Reuters) — Uber expects it will be a long tim...
# 5087         5087  Please enable Javascript to watch this video\n...
# 18828       18828  A Gynaecologist, Dr Kenneth Adedugba, of Life ...
#
#                   domain                                              title  \
# 21763  theepochtimes.com  A Silent Rally Remembers Historic Appeal 20 Ye...
# 22823           necn.com  Families of Overdose Victims Rally for Safe In...
# 23162    venturebeat.com  Uber expects a long wait before self-driving c...
# 5087         fox2now.com  A multimillion-dollar contract, a mysterious s...
# 18828    vanguardngr.com  ‘Men will continue to produce sperm until old ...
#
#              date                         authors  ind30k  \
# 21763  2019-04-15                             NaN    3551
# 22823  2019-04-08                             NaN    8108
# 23162  2019-04-09                          Author   22427
# 5087   2019-04-12                     Chris Hayes    3312
# 18828  2019-04-07  View All Posts Nwafor Polycarp     827
#
#                                                      url    label  \
# 21763  https://www.theepochtimes.com/a-silent-rally-r...    human
# 22823  https://www.necn.com/news/new-england/Families...  machine
# 23162  https://venturebeat.com/2019/04/08/uber-expect...    human
# 5087   https://fox2now.com/2019/04/11/a-multimillion-...  machine
# 18828  https://www.vanguardngr.com/2019/04/men-will-c...    human
#
#          orig_split  split  random_score     top_p
# 21763           gen   test      0.616154       NaN
# 22823           gen   test           NaN  0.939683
# 23162  train_burner   test      1.009594       NaN
# 5087            gen  train           NaN  0.939683
# 18828           gen   test     -0.039887       NaN

# %%
grover['label'].value_counts()
# Out:
# label
# human      15000
# machine    10000
# Name: count, dtype: int64

# %%
machine_grover = grover[grover['label'] == 'machine']
human_grover = grover[grover['label'] == 'human'].sample(n = 10000)
combined_grover = pd.concat([machine_grover, human_grover])

# %%
combined_grover['Label'] = combined_grover['label'].apply(lambda x: x.capitalize())
combined_grover['Original dataset'] = 'grover'
combined_grover['Row in original dataset'] = combined_grover.index
combined_grover.rename(columns = {'article':'Text'}, inplace = True)

# %%
combined_grover = combined_grover[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_grover['Source'] = 'grover'

# %%
combined_grover
# Out:
#                                                     Text    Label  \
# 1      When I first started looking at oil assets, I ...  Machine
# 4      The Kingston and St Andrew Municipal Corporati...  Machine
# 5      news, local-news,\nTwo protests against an inv...  Machine
# 7      Drink-driving charges brought against Danny Dr...  Machine
# 13     Called by the Mirror after today's strong new ...  Machine
# ...                                                  ...      ...
# 2642   TONY PULIS thinks Dael Fry has all the attribu...    Human
# 2907   My favorite way to get to know a city is bite ...    Human
# 17957  Other stars who will select the winners in the...    Human
# 14402  New Delhi: Private equity (PE) fund Actis Llp ...    Human
# 1110   Lucky Charms is teasing us yet again with a ma...    Human
#
#       Original dataset  Row in original dataset  Source
# 1               grover                        1  grover
# 4               grover                        4  grover
# 5               grover                        5  grover
# 7               grover                        7  grover
# 13              grover                       13  grover
# ...                ...                      ...     ...
# 2642            grover                     2642  grover
# 2907            grover                     2907  grover
# 17957           grover                    17957  grover
# 14402           grover                    14402  grover
# 1110            grover                     1110  grover
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Processing reviews

# %%
reviews.sample(5)
# Out:
#                            category  rating    Label  \
# 28806                       Books_5     4.0  Machine
# 28758                       Books_5     4.0  Machine
# 3804             Home_and_Kitchen_5     3.0  Machine
# 32997              Toys_and_Games_5     4.0  Machine
# 18633  Tools_and_Home_Improvement_5     4.0  Machine
#
#                                                     Text
# 28806  I love the characters in this book and the wri...
# 28758  well done just too dark and violent, with the ...
# 3804   I'm pretty torn about this, but I thought it w...
# 32997  Well made and wonderful toys.Cute and very fun...
# 18633  Very cool light (UV 3) and the wide beam is go...

# %%
reviews['label'] = reviews['label'].apply(lambda x: 'Human' if x == 'OR' else 'Machine')
reviews.rename(columns = {'label':'Label', 'text_':'Text'}, inplace=True)

# %%
machine_reviews = reviews[reviews['Label'] == 'Machine'].sample(n = 10000)
human_reviews = reviews[reviews['Label'] == 'Human'].sample(n = 10000)
combined_reviews = pd.concat([machine_reviews, human_reviews])

# %%
combined_reviews['Original dataset'] = 'reviews'
combined_reviews['Row in original dataset'] = combined_reviews.index
combined_reviews = combined_reviews[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_reviews['Source'] = "GPT-2"

# %%
combined_reviews
# Out:
#                            category  rating    Label  \
# 16915  Tools_and_Home_Improvement_5     5.0  Machine
# 17501  Tools_and_Home_Improvement_5     5.0  Machine
# 33416              Toys_and_Games_5     3.0  Machine
# 38131  Clothing_Shoes_and_Jewelry_5     5.0  Machine
# 426              Home_and_Kitchen_5     5.0  Machine
# ...                             ...     ...      ...
# 40355  Clothing_Shoes_and_Jewelry_5     4.0    Human
# 18745  Tools_and_Home_Improvement_5     4.0    Human
# 38663  Clothing_Shoes_and_Jewelry_5     5.0    Human
# 3429             Home_and_Kitchen_5     4.0    Human
# 32541                       Books_5     5.0    Human
#
#                                                     Text Source
# 16915  My walking 9 month old, I couldn't find a good...  GPT-2
# 17501  This is a great tool, it's lightweight and eas...  GPT-2
# 33416  Too many small pieces that go into the pieces,...  GPT-2
# 38131  I love this bag! It looks great and the materi...  GPT-2
# 426    Very pretty and the size is perfect.  It is th...  GPT-2
# ...                                                  ...    ...
# 40355  This is the first smart watch I've used, but I...  GPT-2
# 18745  Do your homework.  If installing these bulbs i...  GPT-2
# 38663  This is one of the most awesome body stockings...  GPT-2
# 3429   We use these on multi-sizes of mason jars for ...  GPT-2
# 32541  Romantic suspense is at its very best with thi...  GPT-2
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Processing wiki

# %%
wiki.sample(5)
# Out:
#         Unnamed: 0        id  \
# 12525        12525  45531058
# 8498          8498   5809498
# 125837      125837  37393652
# 99586        99586  38068406
# 8987          8987  22983863
#
#                                                       url  \
# 12525           https://en.wikipedia.org/wiki/Kanakanjali
# 8498                 https://en.wikipedia.org/wiki/VPS/VM
# 125837         https://en.wikipedia.org/wiki/Trap%20music
# 99586         https://en.wikipedia.org/wiki/66%20Ophiuchi
# 8987    https://en.wikipedia.org/wiki/Deng%20Yujiao%20...
#
#                        title  \
# 12525            Kanakanjali
# 8498                  VPS/VM
# 125837            Trap music
# 99586            66 Ophiuchi
# 8987    Deng Yujiao incident
#
#                                                wiki_intro  \
# 12525   Kanakanjali is a Bengali television serial whi...
# 8498    VPS/VM (Virtual Processing System/Virtual Mach...
# 125837  Trap is a subgenre of hip hop music, that orig...
# 99586   66 Ophiuchi is a binary variable star in the e...
# 8987    The Deng Yujiao incident  occurred on 10 May 2...
#
#                                           generated_intro  title_len  \
# 12525   Kanakanjali is a Bengali television serial whi...          1
# 8498    VPS/VM (Virtual Processing System/Virtual Mach...          1
# 125837  Trap is a subgenre of hip hop that emerged in ...          2
# 99586   66 Ophiuchi is a binary variable star system i...          2
# 8987    The Deng Yujiao incident  occurred on January ...          3
#
#         wiki_intro_len  generated_intro_len  \
# 12525              228                  113
# 8498               158                   30
# 125837             160                   72
# 99586              235                   56
# 8987               208                  117
#
#                                                    prompt  \
# 12525   200 word wikipedia style introduction on 'Kana...
# 8498    200 word wikipedia style introduction on 'VPS/...
# 125837  200 word wikipedia style introduction on 'Trap...
# 99586   200 word wikipedia style introduction on '66 O...
# 8987    200 word wikipedia style introduction on 'Deng...
#
#                                            generated_text  prompt_tokens  \
# 12525    aired on GEC channel from 1999 to 2000. It is...             31
# 8498     early type of computer which was used in the ...             31
# 125837   that emerged in the early 2010s. It is a comb...             24
# 99586    system in the constellation Ophiuchus. It is ...             26
# 8987     January 6, 1986, when Deng Yujiao, then a hig...             28
#
#         generated_text_tokens
# 12525                     145
# 8498                       27
# 125837                     84
# 99586                      62
# 8987                      140

# %%
wiki = wiki.sample(n = 20000)

# %%
human_wiki = pd.DataFrame(wiki.iloc[:10000])
machine_wiki = pd.DataFrame(wiki.iloc[10000:])

# %%
human_wiki.rename(columns = {'wiki_intro':'Text'}, inplace = True)
machine_wiki.rename(columns = {'generated_intro':'Text'}, inplace = True)

# %%
human_wiki['Label'] = 'Human'
machine_wiki['Label'] = 'Machine'

# %%
combined_wiki = pd.concat([human_wiki, machine_wiki])

# %%
combined_wiki['Original dataset'] = 'wiki'
combined_wiki['Row in original dataset'] = combined_wiki.index
combined_wiki = combined_wiki[['Text', 'Label', 'Original dataset', 'Row in original dataset']]

# %%
combined_wiki['Source'] = "GPT-3 (Curie)"

# %%
combined_wiki
# Out:
#                                                      Text    Label  \
# 13424   Glycan nomenclature is the systematic naming o...    Human
# 54775   Johannes Kotkas (3 February 1915 – 8 May 1998)...    Human
# 18866   Siruseri is a southern suburb of Chennai, Indi...    Human
# 129302  is a Japanese actor and singer associated with...    Human
# 78312   Roger Charles Alperin (January 8, 1947 – Novem...    Human
# ...                                                   ...      ...
# 84969   In decision theory, a score function, or scori...  Machine
# 45878   James Bernard Fagan (18 May 1873 – 10 July 195...  Machine
# 130325  Hervé Bléjean is a military officer of the Fre...  Machine
# 102299  Stade Brestois 29 is a French football club ba...  Machine
# 144006  Shivgarh is a village and corresponding commun...  Machine
#
#        Original dataset  Row in original dataset         Source
# 13424              wiki                    13424  GPT-3 (Curie)
# 54775              wiki                    54775  GPT-3 (Curie)
# 18866              wiki                    18866  GPT-3 (Curie)
# 129302             wiki                   129302  GPT-3 (Curie)
# 78312              wiki                    78312  GPT-3 (Curie)
# ...                 ...                      ...            ...
# 84969              wiki                    84969  GPT-3 (Curie)
# 45878              wiki                    45878  GPT-3 (Curie)
# 130325             wiki                   130325  GPT-3 (Curie)
# 102299             wiki                   102299  GPT-3 (Curie)
# 144006             wiki                   144006  GPT-3 (Curie)
#
# [20000 rows x 5 columns]

# %% [markdown]
# ### Putting it all together

# %%
combined = pd.concat([combined_essays, combined_grover, combined_reviews, combined_wiki])

# %%
combined.to_csv('combined_data.csv', index = False)

# %%
combined['Label'].value_counts()
# Out:
# Label
# Machine    40000
# Human      40000
# Name: count, dtype: int64

# %%
combined['Original dataset'].value_counts()
# Out:
# Original dataset
# essays    20000
# grover    20000
# wiki      20000
# Name: count, dtype: int64

# %%
combined
# Out:
#                                                      Text    Label  \
# 12494   Hi my name is Timmy and I’m in grade 7. Homewo...  Machine
# 6853    Graduating from high school a year early may s...  Machine
# 14687    Dear state senator,\n\nI am writing to expres...  Machine
# 465     Cell phones have become an essential part of o...  Machine
# 14846   Dear Senator,\n\nI am writing to you today to ...  Machine
# ...                                                   ...      ...
# 84969   In decision theory, a score function, or scori...  Machine
# 45878   James Bernard Fagan (18 May 1873 – 10 July 195...  Machine
# 130325  Hervé Bléjean is a military officer of the Fre...  Machine
# 102299  Stade Brestois 29 is a French football club ba...  Machine
# 144006  Shivgarh is a village and corresponding commun...  Machine
#
#                 Source Original dataset  Row in original dataset category  \
# 12494     llama_70b_v1           essays                  12494.0      NaN
# 6853     chat_gpt_moth           essays                   6853.0      NaN
# 14687   cohere-command           essays                  14687.0      NaN
# 465     falcon_180b_v1           essays                    465.0      NaN
# 14846    kingki19_palm           essays                  14846.0      NaN
# ...                ...              ...                      ...      ...
# 84969    GPT-3 (Curie)             wiki                  84969.0      NaN
# 45878    GPT-3 (Curie)             wiki                  45878.0      NaN
# 130325   GPT-3 (Curie)             wiki                 130325.0      NaN
# 102299   GPT-3 (Curie)             wiki                 102299.0      NaN
# 144006   GPT-3 (Curie)             wiki                 144006.0      NaN
#
#         rating
# 12494      NaN
# 6853       NaN
# 14687      NaN
# 465        NaN
# 14846      NaN
# ...        ...
# 84969      NaN
# 45878      NaN
# 130325     NaN
# 102299     NaN
# 144006     NaN
#
# [80000 rows x 7 columns]
